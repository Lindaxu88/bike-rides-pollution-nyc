# %%
# !pip install -q pyspark findspark

# %%
import findspark
findspark.init()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/405 Final Project"
# Out:
# /content/drive/MyDrive/405 Final Project

# %%
# !ls
# Out:
# '2017_citibike_morning_rush_07_09 (1).csv'    Revised_spark.ipynb
#  2017_citibike_morning_rush_07_09.csv	      Revised_spark.py
# '2018_citibike_morning_hours_07_09 (1).csv'  'SLIDES + README草稿'
#  2018_citibike_morning_hours_07_09.csv	     'Spark in-class demo.ipynb'
# '2019_citibike_morning_rush_07_09 (1).csv'    spark.py
#  2019_citibike_morning_rush_07_09.csv	     'Spark w New Data'
# '2019 October Region.ipynb'		     'Test Run spark.ipynb'
#  Air_Quality.csv			     'V2 spark-job.ipynb'
# 'Borough Division.ipynb'		      v2_spark.py
# 'Final Project Duck DB.sql'		      v3_spark.py
#  joined_output				      v4_spark.py
#  nyc_air_quality_1719.csv		      垃圾箱（用于存放老版本文件）
#  pipeline.sh

# %%
# !spark-submit spark.py \
    "2017_citibike_morning_rush_07_09.csv,2018_citibike_morning_hours_07_09.csv,2019_citibike_morning_rush_07_09.csv" \
    "nyc_air_quality_1719.csv" \
    "joined_output"
# Out:
# Streaming output truncated to the last 5000 lines.
#   } ]
# }
# and corresponding Parquet message type:
# message spark_schema {
#   optional binary trip_duration (STRING);
#   optional binary start_station_id (STRING);
#   optional double start_station_latitude;
#   optional double start_station_longitude;
#   optional binary end_station_id (STRING);
#   optional binary user_type (STRING);
#   optional int96 trip_start_timestamp;
#   required int64 ride_id;
#   optional binary Local Site Name (STRING);
#   optional binary County (STRING);
#   optional int32 date (DATE);
#   optional double site_latitude;
#   optional double site_longitude;
#   optional double avg_pm25;
#   optional double avg_aqi;
#   optional double squared_distance;
# }
#
#
# 25/03/13 18:14:57 INFO CodecConfig: Compression: SNAPPY
# 25/03/13 18:14:57 INFO CodecConfig: Compression: SNAPPY
# ...

# %%
# !spark-submit v2_spark.py \
    "2017_citibike_morning_rush_07_09.csv,2018_citibike_morning_hours_07_09.csv,2019_citibike_morning_rush_07_09.csv" \
    "Air_Quality.csv" \
    "joined_output"
